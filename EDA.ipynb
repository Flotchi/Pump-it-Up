# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('clean_training_set.csv',index_col='id')

# %%
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
data.head()
# Out:
#        amount_tsh        funder   gps_height     installer  longitude  \
# id
# 69572      6000.0         roman  1390.000000         roman  34.938093
# 8776        200.0       grumeti  1399.000000       grumeti  34.698766
# 34310        25.0  lottery club   686.000000  world vision  37.460664
# 67743        50.0        unicef   263.000000        unicef  38.486161
# 19728       500.0   action in a  1027.925202       artisan  31.130847
#
#         latitude                    basin   region  district_code        ward  \
# id
# 69572  -9.856322               lake nyasa   iringa              5    mundindi
# 8776   -2.147466            lake victoria     mara              2       natta
# 34310  -3.821329                  pangani  manyara              4     ngorika
# 67743 -11.155298  ruvuma / southern coast   mtwara             63    nanyumbu
# 19728  -1.825359            lake victoria   kagera              1  nyakasimbi
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59400 entries, 69572 to 26348
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   amount_tsh         59400 non-null  float64
#  1   funder             59400 non-null  object
#  2   gps_height         59400 non-null  float64
#  3   installer          59400 non-null  object
#  4   longitude          59400 non-null  float64
#  5   latitude           59400 non-null  float64
#  6   basin              59400 non-null  object
#  7   region             59400 non-null  object
#  8   district_code      59400 non-null  int64
#  9   ward               59400 non-null  object
#  10  population         59400 non-null  float64
#  11  scheme_management  59400 non-null  object
#  12  extraction_type    59400 non-null  object
#  13  management         59400 non-null  object
#  14  payment_type       59400 non-null  object
#  15  water_quality      59400 non-null  object
# ...

# %%
data.describe()
# Out:
#           amount_tsh    gps_height     longitude      latitude  district_code  \
# count   59400.000000  59400.000000  59400.000000  5.940000e+04   59400.000000
# mean      664.876311   1072.274192     35.106608 -5.706033e+00       5.629747
# std      3131.791560    512.414629      2.580356  2.946019e+00       9.633649
# min         0.200000    -90.000000     29.607122 -1.164944e+01       0.000000
# 25%        50.000000    838.000000     33.271875 -8.540621e+00       2.000000
# 50%       250.000000   1205.511166     34.908743 -5.021597e+00       3.000000
# 75%       500.000000   1350.981707     37.178387 -3.326156e+00       5.000000
# max    350000.000000   2770.000000     40.345193 -2.000000e-08      80.000000
#
#          population  operation_time
# count  59400.000000    59400.000000
# mean     291.933544       13.633182
# std      463.223380       10.561568
# min        1.000000       -7.000000
# 25%       80.000000        7.000000
# 50%      200.000000       11.000000
# ...

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=data, x='extraction_type_class', hue='status_group')
# Out:
# <AxesSubplot:xlabel='extraction_type_class', ylabel='count'>

# %%
#la qualité de l'eau a un impact. Les eaux de bonne qualité presentent plus de pompes fonctionneles. les eaux salées presente des pompes defaillantes

# %%
sns.countplot(data=data, x='quantity', hue='status_group')
# Out:
# <AxesSubplot:xlabel='quantity', ylabel='count'>

# %%
#les pompes les + resitantes sont sur une quantité d'eau suffisante. Les zones seches sont propices a des pompes defaillantes

# %%
#les pompes qui semblent le mieux resister sont celles qui fonctionnent par gravitée. Les pompes qui ont tendance a etre defaillantes sont les submersible, swn80 et mono

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=data, x='region', hue='status_group')
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
#certaines régions présentes beaucoup de pompes non fonctionnelles (mara, mtwara, mwanza,...)

# %%
plt.figure(figsize=(20,8))
plt.hist(data["gps_height"], bins=50, color="blue", alpha=0.7, edgecolor="black")
# Out:
# (array([2.490e+02, 1.961e+03, 1.354e+03, 8.450e+02, 7.140e+02, 8.330e+02,
#         1.706e+03, 1.606e+03, 9.110e+02, 8.810e+02, 6.540e+02, 3.610e+02,
#         5.210e+02, 9.280e+02, 5.410e+02, 6.110e+02, 6.840e+02, 6.860e+02,
#         2.575e+03, 5.528e+03, 1.951e+03, 1.161e+03, 5.470e+03, 4.079e+03,
#         2.897e+03, 6.606e+03, 1.511e+03, 2.204e+03, 1.546e+03, 1.587e+03,
#         1.294e+03, 1.056e+03, 9.290e+02, 6.290e+02, 4.710e+02, 4.280e+02,
#         3.290e+02, 2.100e+02, 2.890e+02, 3.020e+02, 9.300e+01, 7.900e+01,
#         7.100e+01, 1.700e+01, 1.000e+01, 1.100e+01, 1.400e+01, 6.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([ -90. ,  -32.8,   24.4,   81.6,  138.8,  196. ,  253.2,  310.4,
#          367.6,  424.8,  482. ,  539.2,  596.4,  653.6,  710.8,  768. ,
#          825.2,  882.4,  939.6,  996.8, 1054. , 1111.2, 1168.4, 1225.6,
#         1282.8, 1340. , 1397.2, 1454.4, 1511.6, 1568.8, 1626. , 1683.2,
# ...

# %%
plt.figure(figsize=(20,8))
plt.hist(data["amount_tsh"], bins=50, color="blue", alpha=0.7, edgecolor="black")
# Out:
# (array([5.8506e+04, 7.7300e+02, 6.9000e+01, 1.1000e+01, 8.0000e+00,
#         8.0000e+00, 3.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 3.0000e+00,
#         0.0000e+00, 7.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([2.00000000e-01, 7.00019600e+03, 1.40001920e+04, 2.10001880e+04,
#         2.80001840e+04, 3.50001800e+04, 4.20001760e+04, 4.90001720e+04,
#         5.60001680e+04, 6.30001640e+04, 7.00001600e+04, 7.70001560e+04,
#         8.40001520e+04, 9.10001480e+04, 9.80001440e+04, 1.05000140e+05,
# ...

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=data, x='basin', hue='status_group')
# Out:
# <AxesSubplot:xlabel='basin', ylabel='count'>

# %%
plt.figure(figsize=(20,8))
plt.hist(data["population"], bins=100, color="blue", alpha=0.7, edgecolor="black")
# Out:
# (array([3.9688e+04, 1.6244e+04, 1.6170e+03, 6.8600e+02, 4.0900e+02,
#         1.1200e+02, 1.8800e+02, 5.2000e+01, 9.5000e+01, 6.2000e+01,
#         2.1000e+01, 3.5000e+01, 8.0000e+00, 3.7000e+01, 1.7000e+01,
#         5.0000e+00, 3.0000e+01, 4.0000e+00, 7.0000e+00, 1.5000e+01,
#         3.0000e+00, 7.0000e+00, 3.4000e+01, 0.0000e+00, 4.0000e+00,
#         0.0000e+00, 6.0000e+00, 1.0000e+00, 1.0000e+00, 4.0000e+00,
#         0.0000e+00, 1.0000e+00, 4.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
# ...
